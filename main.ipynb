# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats
import numpy as np

from data import get_data

# %%
spy = get_data("SPY")
# Out:
# The size of  SPY is  (253, 7)

# %%
syf = get_data("SYF")
# Out:
# The size of  SYF is  (253, 6)

# %%
plt.scatter(spy.returns, syf.returns)
plt.xlim(-0.05, 0.05)
plt.ylim(-0.1, 0.1)
plt.title("SYF")
plt.xlabel("SPY return")
plt.ylabel("SYF return")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
